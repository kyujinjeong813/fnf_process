# %%
import pandas as pd

file_path = 'C://Users/kyujin/Desktop/PROCESS/MKT/DX/6월_DX마케팅_프로세스팀_인플루언서_CONTENTS LIST_DATA_200702.xlsx'
sheet_name = '인플루언서 별도 시트'
cols = ['중분류', '소분류', '품번', '플랫폼', '진행업체', '진행비용(\)','제품비용(\)',
        'ID/이름/채널명','업로드 날짜', '주차', '업로드 URL', '팔로워/구독자 수', '좋아요', '댓글', '업로드일정','해시태그','퀄리티']

df_mkt = pd.read_excel(file_path, sheet_name=sheet_name, header=2)
df_mkt = df_mkt.iloc[:, 4:31]
df_mkt.dropna(thresh=15, inplace=True)
df_mkt.drop(df_mkt.tail(1).index, inplace=True)
df_mkt = df_mkt[cols]

df_mkt
# Out:
#      중분류      소분류         품번    플랫폼  진행업체 진행비용(\) 제품비용(\)         ID/이름/채널명  \
# 2558  BK  라이크에어백팩  DXBK31011    네이버  애드마인  100000   39750             카모마일T
# 2559  BK  라이크에어백팩  DXBK31011    네이버  애드마인  100000   39750               부기태
# 2560  BK  라이크에어백팩  DXBK31011    네이버  애드마인  100000   39750             딸기소보루
# 2561  BK  라이크에어백팩  DXBK31011    네이버  애드마인  100000   39750              도리도리
# 2562  BK  라이크에어백팩  DXBK31011    네이버  애드마인  100000   39750                도록
# ...   ..      ...        ...    ...   ...     ...     ...               ...
# 4335  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           mkhiya1
# 4336  TS    키즈카라티  DKTS53031  인스타그램    본사       0       0          fufujaru
# 4337  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           joohea8
# 4338  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           0227csm
# 4339  TS    키즈카라티  DKTS53031  인스타그램    본사       0       0  hakunamatata0809
#
#                    업로드 날짜    주차  \
# 2558  2020-01-13 00:00:00   3.0
# 2559  2020-01-14 00:00:00   3.0
# 2560  2020-01-15 00:00:00   3.0
# 2561  2020-01-15 00:00:00   3.0
# 2562  2020-01-15 00:00:00   3.0
# ...                   ...   ...
# 4335  2020-06-09 00:00:00  24.0
# 4336  2020-06-30 00:00:00  27.0
# 4337  2020-06-14 00:00:00  24.0
# 4338  2020-06-17 00:00:00  25.0
# 4339  2020-06-19 00:00:00  25.0
#
#                                               업로드 URL 팔로워/구독자 수  좋아요  댓글  \
# 2558  https://blog.naver.com/chamomile_t/221768044015       NaN   27  10
# 2559              https://llillo.blog.me/221770939442       NaN   54   8
# 2560                    http://ddalso.kr/221773263226       NaN   55   7
# 2561            https://duck0231.blog.me/221772008290       NaN    3   0
# 2562      https://blog.naver.com/dohyemm/221772648851       NaN   46  20
# ...                                               ...       ...  ...  ..
# 4335         https://www.instagram.com/p/CBMwnldnma-/     88200  778  20
# 4336         https://www.instagram.com/p/CCAsM-SHAmf/     11600  336   0
# 4337         https://www.instagram.com/p/CBaK1eHgBCx/     63800  675  19
# 4338         https://www.instagram.com/p/CBcTb6BFsnS/     86800  737   8
# 4339         https://www.instagram.com/p/CBmDq7wJ2XJ/     86700  883   1
#
#      업로드일정 해시태그  퀄리티
# 2558   NaN  NaN  NaN
# 2559   NaN  NaN  NaN
# 2560   NaN  NaN  NaN
# 2561   NaN  NaN  NaN
# 2562   NaN  NaN  NaN
# ...    ...  ...  ...
# 4335   NaN  NaN  NaN
# 4336   NaN  NaN  NaN
# 4337   NaN  NaN  NaN
# 4338   NaN  NaN  NaN
# 4339   NaN  NaN  NaN
#
# [1782 rows x 17 columns]

# %%
df_insta = df_mkt[df_mkt['플랫폼']=='인스타그램']
df_insta['인터랙션총량'] = df_insta['좋아요'] + df_insta['댓글']*5
#df_insta.dropna(subset=['해시태그','퀄리티'], inplace=True)

df_insta
# Out:
# C:\Users\kyujin\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      중분류      소분류         품번    플랫폼  진행업체 진행비용(\) 제품비용(\)         ID/이름/채널명  \
# 2578  BK  라이크에어백팩  DXBK31011  인스타그램  애드마인   50000       0             카모마일T
# 2579  BK  라이크에어백팩  DXBK31011  인스타그램  애드마인   50000       0               부기태
# 2580  BK  라이크에어백팩  DXBK31011  인스타그램  애드마인   50000       0              코코다니
# 2581  BK  라이크에어백팩  DXBK31011  인스타그램  애드마인   50000       0             딸기소보루
# 2582  BK  라이크에어백팩  DXBK31011  인스타그램  애드마인   50000       0                도록
# ...   ..      ...        ...    ...   ...     ...     ...               ...
# 4335  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           mkhiya1
# 4336  TS    키즈카라티  DKTS53031  인스타그램    본사       0       0          fufujaru
# 4337  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           joohea8
# 4338  TS    키즈카라티  DKTS52031  인스타그램    본사       0       0           0227csm
# 4339  TS    키즈카라티  DKTS53031  인스타그램    본사       0       0  hakunamatata0809
#
#                    업로드 날짜    주차                                   업로드 URL  \
# 2578  2020-01-12 00:00:00   2.0  https://www.instagram.com/p/B7NXwrQHRiv/
# 2579  2020-01-14 00:00:00   3.0  https://www.instagram.com/p/B7SgI3GFiW5/
# 2580  2020-01-15 00:00:00   3.0  https://www.instagram.com/p/B7VAKI6nSWD/
# 2581  2020-01-15 00:00:00   3.0  https://www.instagram.com/p/B7V7S_bhSal/
# 2582  2020-01-15 00:00:00   3.0  https://www.instagram.com/p/B7VaoVVnIWt/
# ...                   ...   ...                                       ...
# 4335  2020-06-09 00:00:00  24.0  https://www.instagram.com/p/CBMwnldnma-/
# 4336  2020-06-30 00:00:00  27.0  https://www.instagram.com/p/CCAsM-SHAmf/
# 4337  2020-06-14 00:00:00  24.0  https://www.instagram.com/p/CBaK1eHgBCx/
# 4338  2020-06-17 00:00:00  25.0  https://www.instagram.com/p/CBcTb6BFsnS/
# 4339  2020-06-19 00:00:00  25.0  https://www.instagram.com/p/CBmDq7wJ2XJ/
#
#      팔로워/구독자 수   좋아요  댓글 업로드일정 해시태그  퀄리티 인터랙션총량
# 2578     72518  4093   7   NaN  NaN  NaN   4128
# 2579     77158  1061  14   NaN  NaN  NaN   1131
# 2580     15497   108   1   NaN  NaN  NaN    113
# 2581     28714   437  31   NaN  NaN  NaN    592
# 2582     29345   129   1   NaN  NaN  NaN    134
# ...        ...   ...  ..   ...  ...  ...    ...
# 4335     88200   778  20   NaN  NaN  NaN    878
# 4336     11600   336   0   NaN  NaN  NaN    336
# 4337     63800   675  19   NaN  NaN  NaN    770
# 4338     86800   737   8   NaN  NaN  NaN    777
# 4339     86700   883   1   NaN  NaN  NaN    888
#
# [1238 rows x 18 columns]
